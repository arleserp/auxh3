# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df_labels = pd.read_csv('csvjoinv2/scalefree+sn+4+eta+1+numSt+97.join.node.csv')
df_features = pd.read_csv('../../network_specs/scalefree.specs.csv', sep=';')

#df_features.drop(columns='state', inplace=True)

# %%
df_labels['State'] = np.where(
    df_labels['State'] == 'Recovered',
    0,
    1
)

# %%
df_labels['State'].value_counts()
# Out:
# 0    99521
# 1      579
# Name: State, dtype: int64

# %%
df_labels['Id'].value_counts()
# Out:
# p84    1001
# p16    1001
# p22    1001
# p28    1001
# p81    1001
#        ...
# p91    1001
# p41    1001
# p99    1001
# p5     1001
# p62    1001
# Name: Id, Length: 100, dtype: int64

# %%
df_no_recover_proba = df_labels.groupby('Id')['State'].mean().reset_index(drop=False)
df_no_recover_proba
# Out:
#      Id  State
# 0    p0    0.0
# 1    p1    0.0
# 2   p10    0.0
# 3   p11    0.0
# 4   p12    0.0
# ..  ...    ...
# 95  p95    0.0
# 96  p96    0.0
# 97  p97    0.0
# 98  p98    0.0
# 99  p99    0.0
#
# [100 rows x 2 columns]

# %%
df_data = df_no_recover_proba.merge(
    df_features,
    on='Id',
    how='left'
)

# %%
df_data['binary_state'] = df_data['State'] > 0.0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(np.abs(df_data.corr()), annot=True)
plt.show()

# %%
sns.pairplot(
    data=df_data[
        ['Eccentricity',
         'closnesscentrality',
         'harmonicclosnesscentrality',
         'State'
        ]
    ]
)

# %%
for col in ['Eccentricity',
         'closnesscentrality',
         'harmonicclosnesscentrality']:
    plt.figure(figsize=(5,5))
    sns.violinplot(
        data=df_data,
        y=col,
        x='binary_state'
    )
    sns.scatterplot(
        data=df_data,
        y=col,
        x='binary_state'
    )
    plt.show()

# %%
for col in ['Eccentricity',
         'closnesscentrality',
         'harmonicclosnesscentrality']:
    plt.figure(figsize=(5,5))
    sns.boxplot(
        data=df_data,
        y=col,
        x='binary_state',
        notch=True
    )
    plt.show()

# %%
joined_result_folder = '../joined_boxplot'

if not os.path.exists(joined_result_folder):
    os.mkdir(joined_result_folder)
    
df_data.to_pickle(f'{joined_result_folder}/scalefree.pkl')
